# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips['total_bill'], kde=True, bins=30)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.pairplot(tips)
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
import numpy as np

sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips, palette='deep')
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_17852\2036244067.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=tips, palette='deep')
# <Axes: xlabel='sex', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.set_style('ticks')
sns.countplot(x='sex', data=tips, palette='deep', ax=ax)

ax.set_xlabel("Eixo x")
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_17852\3294763253.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=tips, palette='deep', ax=ax)
# Text(0.5, 0, 'Eixo x')

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='rainbow')
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_17852\2053818160.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='total_bill', data=tips, palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex', palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, palette='rainbow', hue='sex', split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['x', 'v'], scatter_kws={'s':100}, aspect=1.6)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', col='time', row='day')

# %%
sns.lmplot(x='total_bill', y='tip', aspect=4, data=tips)

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pivotFlights = flights.pivot_table(index='year', columns='month', values='passengers')
pivotFlights
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_17852\3668958945.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivotFlights = flights.pivot_table(index='year', columns='month', values='passengers')
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# year
# 1949   112.0  118.0  132.0  129.0  121.0  135.0  148.0  148.0  136.0  119.0
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
# 1954   204.0  188.0  235.0  227.0  234.0  264.0  302.0  293.0  259.0  229.0
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 8))
sns.heatmap(pivotFlights, ax=ax, annot=True, fmt='.0f', linewidths=1, linecolor='white', cmap='magma')
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.clustermap(pivotFlights, standard_scale=0.5)
